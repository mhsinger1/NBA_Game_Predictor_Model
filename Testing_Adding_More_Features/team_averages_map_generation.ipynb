# %% [markdown]
# This file generates a map from team names to their season average stats.

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
df = pd.read_csv('/content/gdrive/MyDrive/M156 Final Project/Testing_Adding_More_Features/data.csv')

# %%
df
# Out:
#      GAME_DATE_EST   GAME_ID SELF_NICKNAME SELF_ABBREV   OPP_NICKNAME  \
# 0       2022-04-10  22101216          Nets         BKN         Pacers
# 1       2022-04-10  22101217       Hornets         CHA        Wizards
# 2       2022-04-10  22101218     Cavaliers         CLE          Bucks
# 3       2022-04-10  22101221       Rockets         HOU          Hawks
# 4       2022-04-10  22101223     Grizzlies         MEM        Celtics
# ...            ...       ...           ...         ...            ...
# 2587    2021-10-04  12100007          Jazz         UTA          Spurs
# 2588    2021-10-04  12100008      Warriors         GSW  Trail Blazers
# 2589    2021-10-04  12100009          Suns         PHX          Kings
# 2590    2021-10-04  12100010       Nuggets         DEN       Clippers
# 2591    2021-10-03  12100001          Nets         BKN         Lakers
#
#      OPP_ABBREV  PTS_self  PTS_opp  FG_PCT_self  FT_PCT_self  FG3_PCT_self  \
# ...

# %%
team_to_avgs = {}

# %%
for index, row in df.iterrows():
    team_to_avgs[row['Team']] = [row['FG%']/100, row['FT%']/100, row['3P%']/100, row['REB'], row['AST']]

# %%
print(team_to_avgs)
# Out:
# {'Timberwolves': [0.457, 0.778, 0.358, 44.2, 25.7], 'Grizzlies': [0.461, 0.7340000000000001, 0.353, 49.2, 26.0], 'Bucks': [0.46799999999999997, 0.7759999999999999, 0.366, 46.7, 23.9], 'Hornets': [0.46799999999999997, 0.74, 0.365, 44.6, 28.1], 'Suns': [0.485, 0.797, 0.364, 45.3, 27.4], 'Hawks': [0.47, 0.812, 0.374, 44.0, 24.6], 'Jazz': [0.47100000000000003, 0.767, 0.36, 46.3, 22.4], 'Spurs': [0.467, 0.754, 0.35200000000000004, 45.3, 27.9], 'Nets': [0.475, 0.805, 0.361, 44.4, 25.3], 'Nuggets': [0.483, 0.795, 0.353, 44.1, 27.8], 'Lakers': [0.469, 0.732, 0.34700000000000003, 44.0, 24.0], 'Celtics': [0.466, 0.816, 0.35600000000000004, 46.1, 24.8], 'Bulls': [0.48, 0.813, 0.369, 42.3, 23.9], 'Pacers': [0.46299999999999997, 0.768, 0.344, 43.9, 25.4], 'Warriors': [0.469, 0.769, 0.364, 45.5, 27.1], 'Kings': [0.46, 0.768, 0.344, 42.9, 23.7], 'Heat': [0.467, 0.8079999999999999, 0.379, 43.7, 25.5], '76ers': [0.466, 0.821, 0.364, 42.3, 23.7], 'Rockets': [0.456, 0.713, 0.349, 42.0, 23.6], 'Raptors'
# ...
